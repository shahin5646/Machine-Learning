# %%
import pandas as pd
import numpy as np

# %%
olympic=pd.read_csv("./bios.csv")

# %%
coffee= pd.read_csv('./coffee.csv')

# %%
olympic.head(15)
# Out:
#     athlete_id                     name   born_date          born_city  \
# 0            1    Jean-François Blanchy  1886-12-12           Bordeaux
# 1            2           Arnaud Boetsch  1969-04-01             Meulan
# 2            3             Jean Borotra  1898-08-13           Biarritz
# 3            4          Jacques Brugnon  1895-05-11        Paris VIIIe
# 4            5             Albert Canet  1878-04-17         Wandsworth
# 5            6        Nicolas Chatelain  1970-01-13             Amiens
# 6            7            Patrick Chila  1969-11-27        Ris-Orangis
# 7            8             Henri Cochet  1901-12-14       Villeurbanne
# 8            9            Marcel Cousin  1896-08-04              Nîmes
# 9           10       Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 10          11  Élie, Comte de Lastours  1874-08-12            Orgeval
# 11          12              Max Decugis  1882-09-24         Paris XVIe
# ...

# %%
olympic.tail(5)
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
#checking Random Values
olympic.sample(12)
# Out:
#         athlete_id                    name   born_date  \
# 116609      118005          Thiago Almeida  1980-01-14
# 130302      132979           Daniel Asenov  1997-05-17
# 10271        10327             Luis Lozano  1945-08-19
# 49783        50141            Karin Singer  1966-05-14
# 49224        49581             Pru Chapman  1950-03-14
# 117313      118799  Maiken Caspersen Falla  1990-08-13
# 28079        28289    Montserrat Artamendi  1941-09-17
# 34293        34558        Hidehiko Yoshida  1969-09-03
# 98402        99198           Peter Zelinka  1957-03-01
# 145085      148797     Anastasiya Prytkova  2002-11-02
# 99603       100402  Riikka Nieminen-Välilä  1973-06-12
# 132908      135818         Artyom Yermakov  1982-03-16
#
#                              born_city                   born_region  \
# 116609                       Cariacica                Espírito Santo
# 130302                        Kukorevo                        Yambol
# ...

# %%
olympic.loc[3:7,["name",'NOC']]
# Out:
#                 name     NOC
# 3    Jacques Brugnon  France
# 4       Albert Canet  France
# 5  Nicolas Chatelain  France
# 6      Patrick Chila  France
# 7       Henri Cochet  France

# %%
olympic.loc[5]
# Out:
# athlete_id                      6
# name            Nicolas Chatelain
# born_date              1970-01-13
# born_city                  Amiens
# born_region                 Somme
# born_country                  FRA
# NOC                        France
# height_cm                   181.0
# weight_kg                    70.0
# died_date                     NaN
# Name: 5, dtype: object

# %%
olympic.loc[[2,5,7,8],["name","height_cm","NOC"]]
# Out:
#                 name  height_cm     NOC
# 2       Jean Borotra      183.0  France
# 5  Nicolas Chatelain      181.0  France
# 7       Henri Cochet        NaN  France
# 8      Marcel Cousin        NaN  France

# %%
olympic.iloc[2:10,[2,4]]
# Out:
#     born_date           born_region
# 2  1898-08-13  Pyrénées-Atlantiques
# 3  1895-05-11                 Paris
# 4  1878-04-17               England
# 5  1970-01-13                 Somme
# 6  1969-11-27               Essonne
# 7  1901-12-14                 Rhône
# 8  1896-08-04                  Gard
# 9  1868-07-16                  Cher

# %%
olympic.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
olympic.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# olympic.loc[1,["name"]] = "Shahin"

# %%
olympic
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
olympic.loc[5:13,["name","born_region","height_cm"]]
# Out:
#                        name born_region  height_cm
# 5         Nicolas Chatelain       Somme      181.0
# 6             Patrick Chila     Essonne      180.0
# 7              Henri Cochet       Rhône        NaN
# 8             Marcel Cousin        Gard        NaN
# 9        Guy de la Chapelle        Cher        NaN
# 10  Élie, Comte de Lastours    Yvelines        NaN
# 11              Max Decugis       Paris        NaN
# 12                J. Defert         NaN        NaN
# 13           Étienne Durand         NaN        NaN

# %%
olympic.sort_values(["name"],ascending=True)
# Out:
#         athlete_id               name   born_date       born_city  \
# 73853        74423       Abdul Rashid  1928-04-25             NaN
# 19821        19960       Abdul Rashid  1922-06-01      Rawalpindi
# 19822        19961       Abdul Rashid  1947-03-03           Bannu
# 113784      115084       Abdul Rashid  1979-02-15        Khanewal
# 23976        24163         Abel Braga  1952-09-01  Rio de Janeiro
# ...            ...                ...         ...             ...
# 104603      105625   Ștefan Vasilache  1979-05-09           Roman
# 104214      105226      Ștefan Vasile  1982-02-17          Brăila
# 32372        32615      Ștefan Zoller  1914-08-27           Sibiu
# 80057        80708  Ștefania Botcariu  1936-01-11        Bistrița
# 99727       100526    Аlex Halcheniuk  1967-07-28           Minsk
#
#                born_region born_country       NOC  height_cm  weight_kg  \
# 73853                  NaN          NaN  Pakistan        NaN        NaN
# ...

# %%
olympic.sort_values(['height_cm',"weight_kg"],ascending=[0,1]).head(13)
# Out:
#         athlete_id                name   born_date         born_city  \
# 89070        89782            Yao Ming  1980-09-12    Xuhui District
# 5781          5804      Tommy Burleson  1952-02-24         Crossnore
# 6978          7013     Arvydas Sabonis  1964-12-19            Kaunas
# 120266      122147        Zhang Zhaoxu  1987-11-18           Binzhou
# 5673          5696      Gunther Behnke  1963-01-19        Leverkusen
# 89075        89787      Roberto Dueñas  1975-11-01            Madrid
# 7188          7226  Vladimir Tkachenko  1957-09-20         Golovinka
# 5089          5108  Viktor Pankrashkin  1957-06-19   Moskva (Moscow)
# 6504          6537         Luc Longley  1969-01-19         Melbourne
# 118676      120415     Dmitry Musersky  1988-10-29          Makiïvka
# 107408      108533    Peter John Ramos  1985-05-23           Fajardo
# 5796          5819       Andy Campbell  1956-07-21         Melbourne
# 5716          5739            Uwe Blab  1962-03-26  München (Munich)
#
# ...

# %%
#filtering 
olympic.loc[olympic['height_cm']>180,["name","NOC","height_cm"]]
# Out:
#                      name            NOC  height_cm
# 1          Arnaud Boetsch         France      183.0
# 2            Jean Borotra         France      183.0
# 5       Nicolas Chatelain         France      181.0
# 16             Guy Forget         France      189.0
# 25          Henri Leconte         France      184.0
# ...                   ...            ...        ...
# 145465  Stanislav Galiyev            ROC      188.0
# 145466     Mikkel Aagaard        Denmark      184.0
# 145468  Justin Abdelkader  United States      187.0
# 145473     Toms Andersons         Latvia      185.0
# 145494      George Wright         Canada      183.0
#
# [35368 rows x 3 columns]

# %%
olympic.loc[(olympic['born_country']=="GBR") & (olympic["weight_kg"]>60),['name','NOC','born_country']]
# Out:
#                    name            NOC born_country
# 40       Julie Bradbury  Great Britain          GBR
# 47           Sara Gomer  Great Britain          GBR
# 48        Alison Gordon  Great Britain          GBR
# 53          Andrea Holt  Great Britain          GBR
# 55           Valda Lake  Great Britain          GBR
# ...                 ...            ...          ...
# 139612   Emily Campbell  Great Britain          GBR
# 139614     Sarah Davies  Great Britain          GBR
# 143563      Alie Rusher  United States          GBR
# 143782      Ben Davison  United States          GBR
# 145005  Peder Kongshaug         Norway          GBR
#
# [2662 rows x 3 columns]

# %%
olympic[olympic["name"].str.contains("Mohammad",case=False)]
# Out:
#         athlete_id                          name   born_date born_city  \
# 7379          7419               Esmail Mohammad  1960-09-04       NaN
# 13398        13480          Mohammad Reza Bajool  1960-03-21       NaN
# 17205        17323             Mohammad Khogaini         NaN       NaN
# 17208        17326       Mohammad Amin Nuristani  1928-01-01       NaN
# 17212        17330        Din Mohammad Nuristani  1928-01-01       NaN
# ...            ...                           ...         ...       ...
# 140328      143834           Mohammadhadi Saravi  1998-01-06      Amol
# 140329      143835  Mohammad Hossein Mohammadian  1992-08-19      Sari
# 140330      143836           Mohammadreza Geraei  1996-07-25    Shiraz
# 140759      144281              Mohammad Al-Wadi  1985-08-17     Amman
# 144049      147714              Mohammad Fotouhi  1990-12-05      Yazd
#
#        born_region born_country                       NOC  height_cm  \
# ...

# %%
olympic[olympic['name'].str.contains('Mohammad|Ahmed',case=False)]
# Out:
#         athlete_id               name   born_date  \
# 1806          1813      Ahmed El-Said  1970-04-15
# 1807          1814      Mahmoud Ahmed  1945-09-12
# 1817          1825     Ahmed El-Gindy  1959-01-21
# 1821          1829  Ahmed El-Minabawi  1928-07-21
# 1823          1831     Ahmed El-Nagar  1964-02-19
# ...            ...                ...         ...
# 140759      144281   Mohammad Al-Wadi  1985-08-17
# 142479      146090        Ahmed Tijan  1995-04-28
# 143947      147605     Ahmed Al-Yaari  2000-01-16
# 143948      147606        Ahmed Ayash  1994-01-01
# 144049      147714   Mohammad Fotouhi  1990-12-05
#
#                           born_city     born_region born_country  \
# 1806              Al-Qahira (Cairo)       Al-Qahira          EGY
# 1807    Al-Iskanderiya (Alexandria)  Al-Iskanderiya          EGY
# 1817                            NaN             NaN          NaN
# 1821              Al-Qahira (Cairo)       Al-Qahira          EGY
# ...

# %%
# olympic.query('born_country=="EGY" and weight_kg>60')

# %%
olympic.query('born_city == "Banjul" and height_cm > 150')
# Out:
#         athlete_id         name   born_date born_city born_region  \
# 68060        68575   Jabou Jawo  1962-04-18    Banjul      Banjul
# 68067        68582   Oumar Faye  1960-01-10    Banjul      Banjul
# 114065      115369  Alhaji Jeng  1981-12-13    Banjul      Banjul
# 142479      146090  Ahmed Tijan  1995-04-28    Banjul      Banjul
#
#        born_country         NOC  height_cm  weight_kg died_date
# 68060           GAM  The Gambia      155.0       55.0       NaN
# 68067           GAM  The Gambia      183.0       80.0       NaN
# 114065          GAM      Sweden      185.0       73.0       NaN
# 142479          GAM       Qatar      187.0        NaN       NaN

# %%
olympic[(olympic["NOC"].isin(['BAN','IND','GBR'])) & (olympic['height_cm']>150) ]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
olympic[(olympic["born_country"].isin(['BAN'])) & (olympic['height_cm']>150) ]
# olympic[(olympic['born_country'].isin(['GBR','EGY','JOR'])) & (olympic['height_cm']>205) ]
# Out:
#         athlete_id                      name   born_date      born_city  \
# 21999        22158             Cecil Kershaw  1895-02-03  Dhaka (Dacca)
# 25614        25806           Subimal Goswami  1938-01-15    Kishoreganj
# 103790      104784                 Asif Khan  1986-02-15          Pabna
# 119401      121209            Mohammed Milon  1993-02-25  Dhaka (Dacca)
# 119426      121236             Sharmin Ratna  1988-03-24         Magura
# 122335      124407  Mohammad Mahfizur Rahman  1993-05-15          Pabna
# 126743      129124              Shirin Akter  1994-10-12       Satkhira
# 129991      132640           Siddikur Rahman  1984-11-20  Dhaka (Dacca)
# 129992      132641         Abdullah Hel Baki  1989-08-01        Gazipur
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# 21999        Dhaka          BAN  Great Britain      173.0        NaN
# 25614        Dhaka          BAN          India      175.0       56.0
# ...

# %% [markdown]
# ##### Coffee Datesets

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee['Price'] = 7

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price
# 0      Monday    Espresso          25      7
# 1      Monday       Latte          15      7
# 2     Tuesday    Espresso          30      7
# 3     Tuesday       Latte          20      7
# 4   Wednesday    Espresso          35      7
# 5   Wednesday       Latte          25      7
# 6    Thursday    Espresso          40      7
# 7    Thursday       Latte          30      7
# 8      Friday    Espresso          45      7
# 9      Friday       Latte          35      7
# 10   Saturday    Espresso          45      7
# 11   Saturday       Latte          35      7
# 12     Sunday    Espresso          45      7
# 13     Sunday       Latte          35      7

# %%
coffee["New Price"] = np.where(coffee['Coffee Type']=="Espresso",7,10)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  Price  New Price
# 0      Monday    Espresso          25      7          7
# 1      Monday       Latte          15      7         10
# 2     Tuesday    Espresso          30      7          7
# 3     Tuesday       Latte          20      7         10
# 4   Wednesday    Espresso          35      7          7
# 5   Wednesday       Latte          25      7         10
# 6    Thursday    Espresso          40      7          7
# 7    Thursday       Latte          30      7         10
# 8      Friday    Espresso          45      7          7
# 9      Friday       Latte          35      7         10
# 10   Saturday    Espresso          45      7          7
# 11   Saturday       Latte          35      7         10
# 12     Sunday    Espresso          45      7          7
# 13     Sunday       Latte          35      7         10
